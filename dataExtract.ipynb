# %% [markdown]
# ## Imports

# %%
import pandas as pd

# %%
import json

# %% [markdown]
# ## Making a dataframe from a csv file

# %%
df = pd.read_csv('./nasdaq_screener_1695101090068.csv')

# %%
df
# Out:
#      Symbol                                               Name Last Sale  \
# 0         A             Agilent Technologies Inc. Common Stock   $112.69
# 1        AA                    Alcoa Corporation Common Stock     $28.85
# 2       AAC  Ares Acquisition Corporation Class A Ordinary ...    $10.73
# 3      AACG   ATA Creativity Global American Depositary Shares     $1.13
# 4      AACI            Armada Acquisition Corp. I Common Stock    $10.70
# ...     ...                                                ...       ...
# 7518   ZVSA             ZyVersa Therapeutics Inc. Common Stock   $0.1321
# 7519    ZWS  Zurn Elkay Water Solutions Corporation Common ...    $28.15
# 7520   ZYME                        Zymeworks Inc. Common Stock     $6.79
# 7521   ZYNE          Zynerba Pharmaceuticals Inc. Common Stock     $1.33
# 7522   ZYXI                            Zynex Inc. Common Stock     $8.04
#
#       Net Change  % Change    Market Cap        Country  IPO Year   Volume  \
# ...

# %% [markdown]
# ## Selecting only the symbol and name column, and converting it to a python dictionary

# %%
dict = df.loc[:,["Symbol","Name"]].to_dict()
dict
# Out:
# {'Symbol': {0: 'A',
#   1: 'AA',
#   2: 'AAC',
#   3: 'AACG',
#   4: 'AACI',
#   5: 'AACIU',
#   6: 'AACIW',
#   7: 'AACT',
#   8: 'AADI',
#   9: 'AAIC',
#   10: 'AAIC^B',
#   11: 'AAIC^C',
#   12: 'AAIN',
#   13: 'AAL',
#   14: 'AAM^A',
#   15: 'AAM^B',
#   16: 'AAMC',
#   17: 'AAME',
#   18: 'AAN',
#   19: 'AAOI',
#   20: 'AAON',
#   21: 'AAP',
#   22: 'AAPL',
#   23: 'AAT',
#   24: 'AAU',
#   25: 'AB',
#   26: 'ABBV',
#   27: 'ABCB',
#   28: 'ABCL',
#   29: 'ABCM',
#   30: 'ABEO',
#   31: 'ABEV',
#   32: 'ABG',
#   33: 'ABIO',
#   34: 'ABL',
#   35: 'ABLLW',
#   36: 'ABLV',
#   37: 'ABLVW',
#   38: 'ABM',
#   39: 'ABNB',
#   40: 'ABOS',
#   41: 'ABR',
#   42: 'ABR^D',
#   43: 'ABR^E',
#   44: 'ABR^F',
#   45: 'ABSI',
#   46: 'ABT',
#   47: 'ABUS',
#   48: 'ABVC',
#   49: 'AC',
#   50: 'ACA',
#   51: 'ACAB',
#   52: 'ACABW',
#   53: 'ACAC',
#   54: 'ACACU',
#   55: 'ACACW',
#   56: 'ACAD',
#   57: 'ACAH',
#   58: 'ACAHW',
#   59: 'ACAQ',
#   60: 'ACAX',
#   61: 'ACAXR',
# ...

# %% [markdown]
# ## Creating an array, and populating it with the data from the dictionary

# %%
array = []

# %%
for symbol, name in zip(list(dict['Symbol'].values()), list(dict['Name'].values())):
    array.append({'symbol': str(symbol), 'name': str(name)})

# %%
array
# Out:
# [{'symbol': 'A', 'name': 'Agilent Technologies Inc. Common Stock'},
#  {'symbol': 'AA', 'name': 'Alcoa Corporation Common Stock '},
#  {'symbol': 'AAC',
#   'name': 'Ares Acquisition Corporation Class A Ordinary Shares'},
#  {'symbol': 'AACG',
#   'name': 'ATA Creativity Global American Depositary Shares'},
#  {'symbol': 'AACI', 'name': 'Armada Acquisition Corp. I Common Stock'},
#  {'symbol': 'AACIU', 'name': 'Armada Acquisition Corp. I Unit'},
#  {'symbol': 'AACIW', 'name': 'Armada Acquisition Corp. I Warrant'},
#  {'symbol': 'AACT',
#   'name': 'Ares Acquisition Corporation II Class A Ordinary Shares'},
#  {'symbol': 'AADI', 'name': 'Aadi Bioscience Inc. Common Stock'},
#  {'symbol': 'AAIC', 'name': 'Arlington Asset Investment Corp Class A (new)'},
#  {'symbol': 'AAIC^B', 'name': 'Arlington Asset Investment Corp 7.00% '},
#  {'symbol': 'AAIC^C',
#   'name': 'Arlington Asset Investment Corp 8.250% Seies C Fixed-to-Floating Rate Cumulative Redeemable Preferred Stock   '},
# ...

# %% [markdown]
# ## Exporting the data as json

# %%
data = json.dumps(array, indent=4)

# %%
with open('data.json', 'w') as file:
    file.write(data)
